# %% [markdown]
# Função em python que lê dois números inteiros (a, b) e gera como resultado as seguintes operações: adição, subtração, multiplicação e divisão.

# %%
def operations(a,b):
  adicao = a + b
  print('O resultado da adicao dos dois números inteiros é {0}'.format(adicao))
  subtracao = a - b
  print('O resultado da subtracao dos dois números inteiros é {0}'.format(subtracao))
  multiplicacao = a * b
  print('O resultado da multiplicacao dos dois números inteiros é {0}'.format(multiplicacao))
  
  if b == 0:
    print('Impossível chegar a um resultado na divisão. No segundo número, informe um que seja diferente de 0')
  else:
    divisao = a / b
    print('O resultado da divisao dos dois números inteiros é {0:.1f}'.format(divisao))

# %%
a = int(input('Digite um número inteiro: '))
b = int(input('Digite outro número inteiro: '))

operations(a,b)
# Out:
# Digite um número inteiro: 7
# Digite outro número inteiro: 2
# O resultado da adicao dos dois números inteiros é 9
# O resultado da subtracao dos dois números inteiros é 5
# O resultado da multiplicacao dos dois números inteiros é 14
# O resultado da divisao dos dois números inteiros é 3.5
